# %%
import pandas as pd

# %%
df1= pd.read_csv('https://raw.githubusercontent.com/gheniabla/datasets/master/companylist-1.csv')
# Out:
#      Symbol                                    Name  LastSale     MarketCap  \
# 0       TXG                      10x Genomics, Inc.    120.14  1.253768e+10
# 1        YI                               111, Inc.      5.95  1.517948e+08
# 2       PIH  1347 Property Insurance Holdings, Inc.      4.42  2.682103e+07
# 3     PIHPP  1347 Property Insurance Holdings, Inc.     24.89  0.000000e+00
# 4      TURN                180 Degree Capital Corp.      1.99  6.193191e+07
# ...     ...                                     ...       ...           ...
# 3718     ZS                           Zscaler, Inc.    127.21  1.660323e+10
# 3719   ZUMZ                             Zumiez Inc.     30.82  7.842164e+08
# 3720   ZYNE           Zynerba Pharmaceuticals, Inc.      3.80  1.111697e+08
# 3721   ZYXI                             Zynex, Inc.     17.22  5.976297e+08
# 3722   ZNGA                              Zynga Inc.      8.38  9.012174e+09
#
#          ADR TSO  IPOyear             Sector  \
# 0            NaN   2019.0      Capital Goods
# 1     25511734.0   2018.0        Health Care
# 2            NaN   2014.0            Finance
# 3            NaN      NaN            Finance
# 4            NaN      NaN            Finance
# ...          ...      ...                ...
# 3718         NaN   2018.0         Technology
# 3719         NaN   2005.0  Consumer Services
# 3720         NaN   2015.0        Health Care
# 3721         NaN      NaN        Health Care
# 3722         NaN   2011.0         Technology
#
#                                                Industry  \
# 0      Biotechnology: Laboratory Analytical Instruments
# 1                              Medical/Nursing Services
# 2                            Property-Casualty Insurers
# 3                            Property-Casualty Insurers
# 4                            Finance/Investors Services
# ...                                                 ...
# 3718                                       EDP Services
# 3719                     Clothing/Shoe/Accessory Stores
# 3720                              Major Pharmaceuticals
# 3721  Biotechnology: Electromedical & Electrotherape...
# 3722                                       EDP Services
#
#                             Summary Quote  Unnamed: 9
# 0       https://old.nasdaq.com/symbol/txg         NaN
# 1        https://old.nasdaq.com/symbol/yi         NaN
# 2       https://old.nasdaq.com/symbol/pih         NaN
# 3     https://old.nasdaq.com/symbol/pihpp         NaN
# 4      https://old.nasdaq.com/symbol/turn         NaN
# ...                                   ...         ...
# 3718     https://old.nasdaq.com/symbol/zs         NaN
# 3719   https://old.nasdaq.com/symbol/zumz         NaN
# 3720   https://old.nasdaq.com/symbol/zyne         NaN
# 3721   https://old.nasdaq.com/symbol/zyxi         NaN
# 3722   https://old.nasdaq.com/symbol/znga         NaN
#
# [3723 rows x 10 columns]

# %%
df2= pd.read_csv('https://raw.githubusercontent.com/gheniabla/datasets/master/companylist-2.csv')
# Out:
#      Symbol                          Name  LastSale     MarketCap  ADR TSO  \
# 0       DDD        3D Systems Corporation      5.21  6.311139e+08      NaN
# 1       MMM                    3M Company    172.38  9.929423e+10      NaN
# 2      WBAI               500.com Limited      3.57  1.535153e+08      NaN
# 3      EGHT                       8x8 Inc     15.19  1.583318e+09      NaN
# 4       AHC         A.H. Belo Corporation      1.48  3.534167e+07      NaN
# ...     ...                           ...       ...           ...      ...
# 3161    ZBH  Zimmer Biomet Holdings, Inc.    142.79  2.956464e+10      NaN
# 3162    ZTS                   Zoetis Inc.    160.47  7.624647e+10      NaN
# 3163    ZTO     ZTO Express (Cayman) Inc.     30.83  2.416747e+10      NaN
# 3164    ZUO                   Zuora, Inc.      9.41  1.112262e+09      NaN
# 3165   ZYME                Zymeworks Inc.     43.35  1.977942e+09      NaN
#
#       IPOyear             Sector                                 Industry  \
# 0         NaN         Technology  Computer Software: Prepackaged Software
# 1         NaN        Health Care               Medical/Dental Instruments
# 2      2013.0  Consumer Services    Services-Misc. Amusement & Recreation
# 3         NaN         Technology                             EDP Services
# 4         NaN  Consumer Services                     Newspapers/Magazines
# ...       ...                ...                                      ...
# 3161      NaN        Health Care                   Industrial Specialties
# 3162   2013.0        Health Care                    Major Pharmaceuticals
# 3163   2016.0     Transportation        Trucking Freight/Courier Services
# 3164   2018.0         Technology  Computer Software: Prepackaged Software
# 3165   2017.0        Health Care                    Major Pharmaceuticals
#
#                            Summary Quote  Unnamed: 9
# 0      https://old.nasdaq.com/symbol/ddd         NaN
# 1      https://old.nasdaq.com/symbol/mmm         NaN
# 2     https://old.nasdaq.com/symbol/wbai         NaN
# 3     https://old.nasdaq.com/symbol/eght         NaN
# 4      https://old.nasdaq.com/symbol/ahc         NaN
# ...                                  ...         ...
# 3161   https://old.nasdaq.com/symbol/zbh         NaN
# 3162   https://old.nasdaq.com/symbol/zts         NaN
# 3163   https://old.nasdaq.com/symbol/zto         NaN
# 3164   https://old.nasdaq.com/symbol/zuo         NaN
# 3165  https://old.nasdaq.com/symbol/zyme         NaN
#
# [3166 rows x 10 columns]

# %%
df3= pd.read_csv('https://raw.githubusercontent.com/gheniabla/datasets/master/companylist-3.csv')
# Out:
#     Symbol                                               Name  LastSale  \
# 0     GOED                                 1847 Goedeker Inc.    7.2000
# 1     XXII                            22nd Century Group, Inc    0.5823
# 2      FAX              Aberdeen Asia-Pacific Income Fund Inc    4.0600
# 3      IAF                 Aberdeen Australia Equity Fund Inc    4.5700
# 4      AEF  Aberdeen Emerging Markets Equity Income Fund, ...    6.7200
# ..     ...                                                ...       ...
# 287    WYY                              WidePoint Corporation    0.5274
# 288    WTT                      Wireless Telecom Group,  Inc.    1.3600
# 289   XTNT                       Xtant Medical Holdings, Inc.    0.9000
# 290   ZDGE                                        Zedge, Inc.    1.4800
# 291    ZOM                     Zomedica Pharmaceuticals Corp.    0.0989
#
#         MarketCap  ADR TSO  IPOyear                 Sector  \
# 0    4.400064e+07      NaN   2020.0      Consumer Services
# 1    8.085480e+07      NaN      NaN  Consumer Non-Durables
# 2    1.005645e+09      NaN   1986.0                    NaN
# 3    1.039324e+08      NaN      NaN                    NaN
# 4    3.410519e+08      NaN      NaN                    NaN
# ..            ...      ...      ...                    ...
# 287  4.452233e+07      NaN      NaN             Technology
# 288  2.944070e+07      NaN      NaN          Capital Goods
# 289  1.191675e+07      NaN      NaN            Health Care
# 290  1.805523e+07      NaN   2016.0             Technology
# 291  5.578469e+07      NaN   2017.0            Health Care
#
#                                               Industry  \
# 0                                     Home Furnishings
# 1                                Farming/Seeds/Milling
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 287                                       EDP Services
# 288                                Electrical Products
# 289  Biotechnology: Biological Products (No Diagnos...
# 290            Computer Software: Prepackaged Software
# 291                              Major Pharmaceuticals
#
#                           Summary Quote  Unnamed: 9
# 0    https://old.nasdaq.com/symbol/goed         NaN
# 1    https://old.nasdaq.com/symbol/xxii         NaN
# 2     https://old.nasdaq.com/symbol/fax         NaN
# 3     https://old.nasdaq.com/symbol/iaf         NaN
# 4     https://old.nasdaq.com/symbol/aef         NaN
# ..                                  ...         ...
# 287   https://old.nasdaq.com/symbol/wyy         NaN
# 288   https://old.nasdaq.com/symbol/wtt         NaN
# 289  https://old.nasdaq.com/symbol/xtnt         NaN
# 290  https://old.nasdaq.com/symbol/zdge         NaN
# 291   https://old.nasdaq.com/symbol/zom         NaN
#
# [292 rows x 10 columns]

# %%
bigdata = pd.concat([df1, df2,df3], ignore_index=True).sort_values(['Symbol'])
bigdata
# Out:
#      Symbol                           Name  LastSale     MarketCap  \
# 3776      A     Agilent Technologies, Inc.     99.60  3.070764e+10
# 3789     AA              Alcoa Corporation     13.45  2.500682e+09
# 324    AACG          ATA Creativity Global      1.09  1.290848e+07
# 300    AACQ        Artius Acquisition Inc.      9.93  0.000000e+00
# 301   AACQU        Artius Acquisition Inc.     10.47  0.000000e+00
# ...     ...                            ...       ...           ...
# 6887    ZUO                    Zuora, Inc.      9.41  1.112262e+09
# 3717    ZVO                     Zovio Inc.      4.23  1.359474e+08
# 6888   ZYME                 Zymeworks Inc.     43.35  1.977942e+09
# 3720   ZYNE  Zynerba Pharmaceuticals, Inc.      3.80  1.111697e+08
# 3721   ZYXI                    Zynex, Inc.     17.22  5.976297e+08
#
#          ADR TSO  IPOyear             Sector  \
# 3776         NaN   1999.0      Capital Goods
# 3789         NaN   2016.0   Basic Industries
# 324   11842642.0      NaN  Consumer Services
# 300          NaN   2020.0            Finance
# 301          NaN   2020.0            Finance
# ...          ...      ...                ...
# 6887         NaN   2018.0         Technology
# 3717         NaN      NaN  Consumer Services
# 6888         NaN   2017.0        Health Care
# 3720         NaN   2015.0        Health Care
# 3721         NaN      NaN        Health Care
#
#                                                Industry  \
# 3776   Biotechnology: Laboratory Analytical Instruments
# 3789                                           Aluminum
# 324                             Other Consumer Services
# 300                                   Business Services
# 301                                   Business Services
# ...                                                 ...
# 6887            Computer Software: Prepackaged Software
# 3717                            Other Consumer Services
# 6888                              Major Pharmaceuticals
# 3720                              Major Pharmaceuticals
# 3721  Biotechnology: Electromedical & Electrotherape...
#
#                             Summary Quote  Unnamed: 9
# 3776      https://old.nasdaq.com/symbol/a         NaN
# 3789     https://old.nasdaq.com/symbol/aa         NaN
# 324    https://old.nasdaq.com/symbol/aacg         NaN
# 300    https://old.nasdaq.com/symbol/aacq         NaN
# 301   https://old.nasdaq.com/symbol/aacqu         NaN
# ...                                   ...         ...
# 6887    https://old.nasdaq.com/symbol/zuo         NaN
# 3717    https://old.nasdaq.com/symbol/zvo         NaN
# 6888   https://old.nasdaq.com/symbol/zyme         NaN
# 3720   https://old.nasdaq.com/symbol/zyne         NaN
# 3721   https://old.nasdaq.com/symbol/zyxi         NaN
#
# [7181 rows x 10 columns]

# %%
bigdata.to_csv('merged.csv',index= False)

# %%
new_index= ['Symbol', 'Name','LastSale', 'MarketCap', 'IPOyear', 'Sector',  'Industry']

# %%
bigdata_sorted = bigdata.sort_values(['MarketCap'],ascending=False).head(15).reindex(columns = new_index)

bigdata_sorted
# Out:
#      Symbol                                             Name  LastSale  \
# 258    AAPL                                       Apple Inc.    110.34
# 2289   MSFT                            Microsoft Corporation    202.91
# 180    AMZN                                 Amazon.com, Inc.   3008.73
# 163    GOOG                                    Alphabet Inc.   1495.53
# 164   GOOGL                                    Alphabet Inc.   1487.04
# 3797   BABA                    Alibaba Group Holding Limited    275.72
# 1124     FB                                   Facebook, Inc.    254.82
# 438    BNTC                           Benitec Biopharma Inc.      7.05
# 5112     TV                              Grupo Televisa S.A.      6.75
# 6732      V                                        Visa Inc.    205.27
# 6452    TSM  Taiwan Semiconductor Manufacturing Company Ltd.     81.91
# 3265   TSLA                                     Tesla, Inc.     423.43
# 5341    JNJ                                Johnson & Johnson    147.17
# 6773    WMT                                     Walmart Inc.    136.69
# 6046     PG                   Procter & Gamble Company (The)    137.52
#
#          MarketCap  IPOyear             Sector  \
# 258   7.548375e+12   1980.0         Technology
# 2289  1.535552e+12   1986.0         Technology
# 180   1.507042e+12   1997.0  Consumer Services
# 163   1.017205e+12   2004.0         Technology
# 164   1.011431e+12      NaN         Technology
# 3797  7.459981e+11   2014.0      Miscellaneous
# 1124  7.259352e+11   2012.0         Technology
# 438   6.795900e+11   2015.0        Health Care
# 5112  4.454201e+11   1993.0  Consumer Services
# 6732  4.367869e+11      NaN      Miscellaneous
# 6452  4.247915e+11   1997.0         Technology
# 3265  3.952889e+11   2010.0      Capital Goods
# 5341  3.874726e+11      NaN        Health Care
# 6773  3.873457e+11      NaN  Consumer Services
# 6046  3.423727e+11      NaN   Basic Industries
#
#                                              Industry
# 258                            Computer Manufacturing
# 2289          Computer Software: Prepackaged Software
# 180                    Catalog/Specialty Distribution
# 163   Computer Software: Programming, Data Processing
# 164   Computer Software: Programming, Data Processing
# 3797                                Business Services
# 1124  Computer Software: Programming, Data Processing
# 438                             Major Pharmaceuticals
# 5112                                     Broadcasting
# 6732                                Business Services
# 6452                                   Semiconductors
# 3265                               Auto Manufacturing
# 5341                            Major Pharmaceuticals
# 6773               Department/Specialty Retail Stores
# 6046                          Package Goods/Cosmetics

# %%
bigdata_sorted.reset_index(inplace=True)
bigdata_sorted = bigdata_sorted.rename(columns = {'index':'Sequence Number'})
bigdata_sorted.to_csv('marketcap.csv', index= False)

# %%
symbol1 = input('please a stock symbol to search: ')
symbol1 = symbol1.upper();
dff = bigdata.loc[bigdata['Symbol']== symbol1]
if dff.empty:
    print("I don't finnd this symbol please enter another symbol ")
else:
    dff = dff[new_index]
    print("Stockes with symbol  is: \n" )
    display(dff)
# Out:
# please a stock symbol to search: g
# Stockes with symbol  is:
#      Symbol             Name  LastSale     MarketCap  IPOyear  \
# 5026      G  Genpact Limited     39.56  7.546918e+09   2007.0
#
#                  Sector               Industry
# 5026  Consumer Services  Professional Services

# %%
# extra coding for myself 
symbol1 = input('please a stock symbol to search: ')
symbol1 = symbol1.upper();
dff = bigdata.loc[bigdata['Symbol']== symbol1]
while(dff.empty):
    print("I don't finnd this symbol please enter another symbol ")
    symbol1 = input('please another stock symbol to search: ')
    symbol1 =  symbol1.upper();
    dff = bigdata.loc[bigdata['Symbol']== symbol1]
dff = dff[new_index]
print("Stockes with symbol  is: \n" )
display(dff)
